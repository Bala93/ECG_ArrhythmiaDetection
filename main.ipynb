# %%
import cv2
import wfdb as wf
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
from lxml import etree
from matplotlib import pyplot as plt
import os

# %matplotlib inline

# %%
# Prepare data access
paths = glob('data/mitdb/*.dat')
paths = [path[:-4] for path in paths]
paths.sort()
print paths
# Out:
# ['data/mitdb/100', 'data/mitdb/101', 'data/mitdb/102', 'data/mitdb/103', 'data/mitdb/104', 'data/mitdb/105', 'data/mitdb/106', 'data/mitdb/107', 'data/mitdb/108', 'data/mitdb/109', 'data/mitdb/111', 'data/mitdb/112', 'data/mitdb/113', 'data/mitdb/114', 'data/mitdb/115', 'data/mitdb/116', 'data/mitdb/117', 'data/mitdb/118', 'data/mitdb/119', 'data/mitdb/121', 'data/mitdb/122', 'data/mitdb/123', 'data/mitdb/124', 'data/mitdb/200', 'data/mitdb/201', 'data/mitdb/202', 'data/mitdb/203', 'data/mitdb/205', 'data/mitdb/207', 'data/mitdb/208', 'data/mitdb/209', 'data/mitdb/210', 'data/mitdb/212', 'data/mitdb/213', 'data/mitdb/214', 'data/mitdb/215', 'data/mitdb/217', 'data/mitdb/219', 'data/mitdb/220', 'data/mitdb/221', 'data/mitdb/222', 'data/mitdb/223', 'data/mitdb/228', 'data/mitdb/230', 'data/mitdb/231', 'data/mitdb/232', 'data/mitdb/233', 'data/mitdb/234']

# %% [markdown]
# # We want only the [beat annotations](http://www.physionet.org/physiobank/annotations.shtml), each as 240 points

# %%
beat_annotations = ['N', 'L', 'R', 'B',
                    'A', 'a', 'J', 'S', 'V',
                    'r', 'F', 'e', 'j', 'n',
                    'E', '/', 'f', 'Q', '?'] 
# 0.5 of how much signal we want per beat
half_qrs = 120

# %% [markdown]
# # Convert all of the data into classified fragments

# %%
# Prepare the final container
base = pd.DataFrame()

for path in tqdm(paths):
    # print 'Working with file:', path
    ann = wf.rdann(path, 'atr')

    record = wf.rdsamp(path)
    
    # We want just the signals
    data = record.p_signals
    
    # Prepare containers
    signals, classes = [], []
    
#     print dir(ann)
    # Beat extraction
    for it, beat in enumerate(ann.symbol):
        if beat in beat_annotations:
            # Defend from the dumb annotation hacking my folder structure
            if beat == '/': beat = 'C'
                
            sta = ann.sample[it] - half_qrs
            end = ann.sample[it] + half_qrs
            qrs = data[sta : end, :]
            
            # This may happen at the edges
            if len(qrs) != 2 * half_qrs: continue
            
            # Keep the channel type in the class name
            for ch in range(2):
                beat_class = '{}_{}'.format(record.signame[ch], beat)
                signals.append(qrs[:, ch])
                classes.append(beat_class)
                
    new_frame = pd.DataFrame({'qrs_data' : signals,
                              'qrs_type' : classes})
    # Cumulate
    base = base.append(new_frame)
# Out:
# 100%|██████████| 48/48 [00:04<00:00, 11.39it/s]

# %% [markdown]
# # Let's see what kinds of qrs types are available
# We only want examples with more than 200 occurances

# %%
classes = base['qrs_type'].value_counts()
ids = classes.iloc[:] > 700
classes = classes.loc[ids]

# Show just the top ten
print classes, classes.shape
# Out:
# MLII_N    74765
# V1_N      65579
# V1_L       8071
# MLII_L     8071
# MLII_R     7257
# MLII_V     7123
# V1_V       7029
# V5_N       5833
# V1_R       5726
# V2_N       3877
# V1_C       3619
# MLII_C     3619
# V5_C       3407
# V2_C       3407
# MLII_A     2546
# V1_A       2498
# V4_R       1531
# MLII_F      802
# V1_F        793
# V5_f        722
# V2_f        722
# Name: qrs_type, dtype: int64 (21,)

# %%
classes
# Out:
# Index([u'MLII_N', u'V1_N', u'V1_L', u'MLII_L', u'MLII_R', u'MLII_V', u'V1_V',
#        u'V5_N', u'V1_R', u'V2_N', u'V1_C', u'MLII_C', u'V5_C', u'V2_C',
#        u'MLII_A', u'V1_A', u'V4_R', u'MLII_F', u'V1_F', u'V5_f', u'V2_f'],
#       dtype='object')

# %%
# Extract just one exemplary qrs
classes = classes
qrs_type = classes[3]
ids = base['qrs_type'] == qrs_type

# Get all of that type
partial = base.loc[ids]

# %%
qrs = partial.iloc[123]['qrs_data']
plt.plot(qrs)
plt.title('QRS of type: {}'.format(qrs_type))

# %% [markdown]
# ## Pure genius transformation of 1D signals into RGB images

# %%
# Stretch helper
def stretch(qrs, final_length):
    xa = np.linspace(0, 1, len(qrs))
    xb = np.linspace(0, 1, final_length)
    
    longer = np.interp(xb, xa, qrs)
    
    return longer

# %%
# Box generator
def get_box(qrs, left_offset):
    # Up and down are trivial
    top = qrs.min()
    bot = qrs.max()
    
    # Find the middle point of the signal
    middle = len(qrs) / 2 + left_offset
    
    # Make boxes with different widths, why not
    box_half = 60 + np.random.randint(80)
    left = middle - box_half
    right = middle + box_half
    
    return left, right, top, bot

# %%
# Constant factors
height = 400
scale_factor = 4

# Reshape to fit the screen
def reshape(qrs, top_offset):
    # Rescale the qrs (and flip)
    qrs = -qrs
    qrs -= qrs.min()
    qrs /= scale_factor

    # Prepare to be and y-position
    qrs = qrs * height
    qrs = qrs.astype('uint16')
    qrs += top_offset
    
    return qrs

# %%
# Keep the tensorflow object_detection API standards for annotations
def make_annotation(img, qrs_type, box, filename, it):
    # Prepare the xml tree ...
    root = etree.Element('annotation')
    
    # Source branch
    source = etree.SubElement(root, 'size')
    e_width = etree.SubElement(source, 'width')
    e_width.text = str(img.shape[0])
    e_height = etree.SubElement(source, 'height')
    e_height.text = str(img.shape[1])
    e_depth = etree.SubElement(source, 'depth')
    e_depth.text = str(img.shape[2])
    
    # Filename
    e_fname = etree.SubElement(root, 'filename')
    e_fname.text = filename
    
    # Object branch
    e_object = etree.SubElement(root, 'object')
    e_class = etree.SubElement(e_object, 'class')
    e_class.text = qrs_type
    
    # Bounding box
    bndbox = etree.SubElement(e_object, 'bndbox')
    xmin = etree.SubElement(bndbox, 'xmin')
    xmin.text = str(box[0])
    xmax = etree.SubElement(bndbox, 'xmax')
    xmax.text = str(box[1])
    
    ymin = etree.SubElement(bndbox, 'ymin')
    ymin.text = str(box[2])
    ymax = etree.SubElement(bndbox, 'ymax')
    ymax.text = str(box[3])
    savepath = 'annotations/xmls/{}_{}.xml'.format(qrs_type, it)
    
    # Use this tree to save it 
    tree = etree.ElementTree(root)
    tree.write(savepath)

# %%
# Prepare the dataset
for qrs_type in tqdm(classes):
    # Get all of that type
    ids = base['qrs_type'] == qrs_type
    partial = base.loc[ids]
    
    # Mess them up
    partial = partial.sample(frac = 1)
    
    for it in range(20):
        qrs = partial.iloc[it]['qrs_data']

        # Randomize on-screen localization
        top_offset = 130 + np.random.randint(-40, 40)
        left_offset = 50 + np.random.randint(-45, 45)

        # What what
        qrs = stretch(qrs, 500)

        # Make it fit the screen
        qrs = reshape(qrs, top_offset)

        # Extract the box
        # left, right, top, bot = get_box(qrs, left_offset)
        box = get_box(qrs, left_offset)

        # Must be tuple
        # pt1 = (right, top)
        # pt2 = (left, bot)

        # Prepare the width dimension
        x = left_offset + np.arange(len(qrs))

        # Merge into draw-able points
        points = zip(x, qrs)
        points = np.array(points)

        # Prepare an empty image of little noise
        img = np.random.randint(42, size = [600, 600, 3], dtype = 'uint8')

        # Draw on the canvas (great color control btw)
        color = (255, 255, 255)
        cv2.polylines(img, [points], False, color, thickness = 7)
        
        # Make it black on white
        img = cv2.bitwise_not(img)

        # Draw a bounnding box
        # cv2.rectangle(img, pt1, pt2, (255, 30, 30), thickness = 4)
        # plt.imshow(img)

        # Write to drive
        filename = '{}_{}.jpeg'.format(qrs_type, it)
        savepath = '/home/balamurali/vignesh/qrs-object/images/' + filename
        cv2.imwrite(savepath, img)
        # Straight to drive
        make_annotation(img, qrs_type, box, filename, it)
# Out:
# 100%|██████████| 21/21 [00:07<00:00,  2.76it/s]

# %% [markdown]
# ## Preview the last one, show the box

# %%
img = cv2.imread('images/MLII_R_9.jpeg')
cv2.rectangle(img,(241,148),(395,350),(255,30,30),thickness=4)
plt.imshow(img)

# %%
# Extract the box
left, right, top, bot = box
# Must be tuple
pt1 = (right, top)
pt2 = (left, bot)

# Draw a bounnding box
cv2.rectangle(img, pt1, pt2, (255, 30, 30), thickness = 4)
plt.imshow(img)

# %% [markdown]
# ## To make the data-set compatible with the tensorflow API we need a label map

# %%
# Export to a text file
label_map = {qrs_type : it for it, qrs_type in enumerate(classes)}

# %%
# json is the first anserw on google about saving dicts
import json
json.dump(label_map, open("label_map.txt",'w'))

# %% [markdown]
# ## Unfortunately the evaluation script is hard-coded enough that we have to conform to the official format of the label_map

# %%
template = 'item {\n  id: %d\n  name: \'%s\'\n}\n'
with open('qrs_label_map.pbtxt', 'w') as fout:
    for it, qrs_type in enumerate(classes):
        # Object Detection API counts from 1
        fout.write(template % (it + 1, qrs_type))
